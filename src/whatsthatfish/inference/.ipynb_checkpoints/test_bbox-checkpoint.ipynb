# %%
from whatsthatfish.src.inference.bbox_inference import BoundingBoxInference
import os
import sys
print(sys.executable)
image_path = "./loaders/classification_images"
files = os.listdir(image_path)[:5]
print(files)

# bbox = BoundingBoxInference(model=)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from whatsthatfish.src.inference.bbox_inference import BoundingBoxInference
#       2 import os
#       3 import sys
#       4 print(sys.executable)
#
# ModuleNotFoundError: No module named 'whatsthatfish'
